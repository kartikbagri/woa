# %% [markdown]
# # Whale Optimisation Algorithms and its variations

# %%
import os
import opfunu
import numpy as np
import pandas as pd
from mealpy.optimizer import Optimizer

# %% [markdown]
# ## Original Whale Optimisation Algorithm

# %%
class OriginalWOA(Optimizer):
    """
    The original version of: Whale Optimization Algorithm (WOA)

    Links:
        1. https://doi.org/10.1016/j.advengsoft.2016.01.008

    Examples
    ~~~~~~~~
    >>> import numpy as np
    >>> from mealpy.swarm_based.WOA import OriginalWOA
    >>>
    >>> def fitness_function(solution):
    >>>     return np.sum(solution**2)
    >>>
    >>> problem_dict1 = {
    >>>     "fit_func": fitness_function,
    >>>     "lb": [-10, -15, -4, -2, -8],
    >>>     "ub": [10, 15, 12, 8, 20],
    >>>     "minmax": "min",
    >>> }
    >>>
    >>> epoch = 1000
    >>> pop_size = 50
    >>> model = OriginalWOA(epoch, pop_size)
    >>> best_position, best_fitness = model.solve(problem_dict1)
    >>> print(f"Solution: {best_position}, Fitness: {best_fitness}")

    References
    ~~~~~~~~~~
    [1] Mirjalili, S. and Lewis, A., 2016. The whale optimization algorithm.
    Advances in engineering software, 95, pp.51-67.
    """

    def __init__(self, epoch=10000, pop_size=100, **kwargs):
        """
        Args:
            epoch (int): maximum number of iterations, default = 10000
            pop_size (int): number of population size, default = 100
        """
        super().__init__(**kwargs)
        self.name = "OriginalWOA"
        self.epoch = self.validator.check_int("epoch", epoch, [1, 100000])
        self.pop_size = self.validator.check_int("pop_size", pop_size, [10, 10000])
        self.set_parameters(["epoch", "pop_size"])
        self.sort_flag = False

    def evolve(self, epoch):
        """
        The main operations (equations) of algorithm. Inherit from Optimizer class

        Args:
            epoch (int): The current iteration
        """
        a = 2 - 2 * epoch / (self.epoch - 1)  # linearly decreased from 2 to 0
        pop_new = []
        for idx in range(0, self.pop_size):
            r = np.random.rand()
            A = 2 * a * r - a
            C = 2 * r
            l = np.random.uniform(-1, 1)
            p = 0.5
            b = 1
            if np.random.uniform() < p:
                if np.abs(A) < 1:
                    D = np.abs(
                        C * self.g_best[self.ID_POS] - self.pop[idx][self.ID_POS]
                    )
                    pos_new = self.g_best[self.ID_POS] - A * D
                else:
                    # x_rand = pop[np.random.np.random.randint(self.pop_size)]         # select random 1 position in pop
                    x_rand = self.create_solution(self.problem.lb, self.problem.ub)
                    D = np.abs(C * x_rand[self.ID_POS] - self.pop[idx][self.ID_POS])
                    pos_new = x_rand[self.ID_POS] - A * D
            else:
                D1 = np.abs(self.g_best[self.ID_POS] - self.pop[idx][self.ID_POS])
                pos_new = (
                    self.g_best[self.ID_POS]
                    + np.exp(b * l) * np.cos(2 * np.pi * l) * D1
                )
            pos_new = self.amend_position(pos_new, self.problem.lb, self.problem.ub)
            pop_new.append([pos_new, None])
            if self.mode not in self.AVAILABLE_MODES:
                target = self.get_target_wrapper(pos_new)
                self.pop[idx] = self.get_better_solution(
                    self.pop[idx], [pos_new, target]
                )
        if self.mode in self.AVAILABLE_MODES:
            pop_new = self.update_target_wrapper_population(pop_new)
            print(len(pop_new))
            self.pop = self.greedy_selection_population(self.pop, pop_new)

# %% [markdown]
# # Results Generation

# %%
benchmark_dict = {
  2014: range(1, 31),
  2017: range(1, 30),
}

# %%
def final_result(model_name):
  WOAResults = {}
  for year in [2014, 2017]:
    for func_num in benchmark_dict[year]:
      func_map_key_name = f'F{func_num}{year}'
      WOAResults[func_map_key_name] = {}
      for dimension in [10, 30, 50, 100]:
        func_name = f'opfunu.cec_based.F42014(ndim={dimension})'
        WOAResults[func_map_key_name][dimension] = {}
        problem = eval(func_name)
        problem_dict = {
          "fit_func": problem.evaluate,
          "lb": problem.lb,
          "ub": problem.ub,
          "minmax": "min",
          "log_to": "file",
          "log_file": "history.log",
          "dim" : dimension
        }
        for pop_size in [10, 20, 30, 40, 50, 70, 100, 200, 300, 400, 500, 700, 1000]:
          run_result = np.array([])
          for _ in range(1, 52):
            epoch = 10000
            pop_size = pop_size
            model = model_name(epoch, pop_size)
            max_fe = 10000 * dimension
            term_dict = {
              "max_fe": max_fe
            }
            best_position, best_fitness = model.solve(problem_dict, termination=term_dict)
            run_result = np.append(run_result, best_fitness)
          WOAResults[func_map_key_name][dimension][pop_size] = np.mean(run_result)
  for key in WOAResults.keys():
    df = pd.DataFrame(WOAResults[key])
    directory_path = f'./results/{model.name}'
    if not os.path.exists(directory_path):
      os.makedirs(directory_path)
    df.to_csv(f'{directory_path}/{key}.csv', index = True)

# %%
class ImprovedWhaleOptimization():
    """class implements the whale optimization algorithm as found at
    http://www.alimirjalili.com/WOA.html
    and
    https://doi.org/10.1016/j.advengsoft.2016.01.008
    """
    """initialize solutions uniform randomly in space"""

    def __init__(self, opt_func, constraints, nsols, b, a, a_step, ndim, maximize=False):
        self._fe = 0
        self._ndim = ndim
        self._opt_func = opt_func # fitness function -> solve method
        self._constraints = constraints # lb, ub -> solve
        self._b = b
        self._a = a
        self._a_step = a_step
        self._maximize = maximize
        self._nsols = nsols
        self._best_solutions = []
        self._sols = self._init_solutions(nsols)

    def get_solutions(self):
        """return solutions"""
        return self._sols

    def optimize(self, t, ngens, max_fe):
        """solutions randomly encircle, search or attack"""
        ranked_sol = self._rank_solutions(self._sols)
        best_sol = ranked_sol[0]
        #include best solution in next generation solutions
        new_sols = [best_sol]

        for s in ranked_sol[1:]:
            if np.random.uniform(0.0, 1.0) > 0.5:
                A = self._compute_A()
                norm_A = np.linalg.norm(A)
                if norm_A < 1.0:
                    new_s = self._encircle(s, best_sol, A)
                else:
                    ###select random sol
                    random_sol = self._sols[np.random.randint(self._sols.shape[0])]
                    new_s = self._search(s, random_sol, A)
            else:
                new_s = self._attack(s, best_sol)
            new_sols.append(self._constrain_solution(new_s))

        de_sol = []
        for s in new_sols:

            if self._fe >= max_fe:
                return

            # mutation
            indices = np.random.randint(0, self._sols.shape[0], (3))

            r1 = self._sols[indices[0]]
            r2 = self._sols[indices[1]]
            r3 = self._sols[indices[2]]

            f = np.random.uniform(0,1)
            v = r1 + f*(r2-r3)
            jrand = np.random.randint(self._sols.shape[1])

            u = v
            #crossover
            for j in range(len(s)):
              if j == jrand:
                u[j] = v[j]
              else:
                u[j] = s[j]

            #selection
            self._fe+=1
            fitness_s = self._opt_func(s)
            self._fe+=1
            fitness_u = self._opt_func(u)
            if self._maximize:
                if fitness_u > fitness_s:
                    de_sol.append(u)
                else:
                    de_sol.append(s)
            else:
                if fitness_u < fitness_s:
                    de_sol.append(u)
                else:
                    de_sol.append(s)

        self._sols = np.stack(de_sol)
        self._a -= self._a_step

    def EOBL(self, sol):
        
        ranked_sol = self._rank_solutions(sol)
        elite_sol = ranked_sol[0]
        opposition_sols = []
        lb = np.min(ranked_sol, axis=0)
        ub = np.max(ranked_sol, axis=0)

        for s in ranked_sol[0:]:
            k = np.random.uniform(0.0, 1.0, size=self._ndim)
            opp_sol = k*(lb+ub)-elite_sol
            constrain_opp_s = []
            for c, s in zip(self._constraints, opp_sol):
                if c[0] > s or c[1] < s:
                    s = np.random.uniform(lb, ub, size=self._ndim)
            constrain_opp_s.append(s)
            opposition_sols.append(constrain_opp_s)

        opposition_sols = np.stack(opposition_sols)

        return opposition_sols

    def _init_solutions(self, nsols):
        """initialize solutions uniform randomly in space"""
        sols = []
        sols = np.random.uniform(self._constraints[0], self._constraints[1], size=(nsols, self._ndim))
        # print(sols)
        sols = np.stack(sols, axis=-1)
        opp_sols = self.EOBL(sols)

        sols = np.concatenate((sols, opp_sols[0]))
        fitness = []
        for s in sols:
            self._fe+=1
            fitness.append(self._opt_func(s))
        sol_fitness = [(f, s) for f, s in zip(fitness, sols)]
        ranked_sol = list(sorted(sol_fitness, key=lambda x:x[0], reverse=self._maximize))
        eobl_sol = []

        for i in range(nsols):
          eobl_sol.append(ranked_sol[i][1])

        sols = np.stack(eobl_sol, axis=0)

        return sols

    def _constrain_solution(self, sol):
        """ensure solutions are valid wrt to constraints"""
        constrain_s = []
        
        # print(self._constraints)

        for i in range(self._ndim):
            if sol[i] < self._constraints[0][i]:
                sol[i] = self._constraints[0][i]
            if sol[i] > self._constraints[1][i]:
                sol[i] = self._constraints[1][i]
            
            constrain_s.append(sol[i])

        return constrain_s

        # for s in sol:
        #     print(s)
        #     if s < self._constraints[0]:
        #         s = self._constraints[0]
        #     if s > self._constraints[1]:
        #         s = self._constraints[1]
                
            # constrain_s.append(s)
        # return constrain_s

    def _rank_solutions(self, sol):
        """find best solution"""
        fitness = []
        for s in sol:
            self._fe+=1
            fitness.append(self._opt_func(s))
        sol_fitness = [(f, s) for f, s in zip(fitness, sol)]
        #best solution is at the front of the list
        ranked_sol = list(sorted(sol_fitness, key=lambda x:x[0], reverse=self._maximize))
        self._best_solutions.append(ranked_sol[0])

        return [ s[1] for s in ranked_sol]

    def best_solutions(self):
        # print('generation best solution history')
        # print('([fitness], [solution])')
        # for s in self._best_solutions:
        #     print(s)
        # print('\n')
        # print('best solution')
        # print('([fitness], [solution])')
        return sorted(self._best_solutions, key=lambda x:x[0], reverse=self._maximize)[0]

    def _compute_A(self):
        r = np.random.uniform(0.0, 1.0, size=self._ndim)
        return (2.0*np.multiply(self._a, r))-self._a

    def _compute_C(self):
        return 2.0*np.random.uniform(0.0, 1.0, size=self._ndim)

    def _encircle(self, sol, best_sol, A):
        D = self._encircle_D(sol, best_sol)
        return best_sol - np.multiply(A, D)

    def _encircle_D(self, sol, best_sol):
        C = self._compute_C()
        D = np.linalg.norm(np.multiply(C, best_sol)  - sol)
        return D

    def _search(self, sol, rand_sol, A):
        D = self._search_D(sol, rand_sol)
        return rand_sol - np.multiply(A, D)

    def _search_D(self, sol, rand_sol):
        C = self._compute_C()
        return np.linalg.norm(np.multiply(C, rand_sol) - sol)

    def _attack(self, sol, best_sol):
        D = np.linalg.norm(best_sol - sol)
        L = np.random.uniform(-1.0, 1.0, size=self._ndim)
        return np.multiply(np.multiply(D,np.exp(self._b*L)), np.cos(2.0*np.pi*L))+best_sol

# %%
class IWOA():

  def __init__(self, epoch, pop_size):
    self.epoch = epoch
    self.pop_size = pop_size

  def solve(self, problem_dict, termination):

      opt_func = problem_dict["fit_func"]

      b = 0.5
      a = 2.0
      a_step = 0.06
      constraints = [problem_dict["lb"], problem_dict["ub"]]
      if problem_dict["minmax"] == "min":
        maximize = False
      else:
        maximize = True

      opt_alg = ImprovedWhaleOptimization(opt_func, constraints, self.pop_size, b, a, a_step, problem_dict["dim"], maximize)

      for t in range(self.epoch):
          opt_alg.optimize(t, self.epoch, termination["max_fe"])
      return opt_alg.best_solutions()

# %%
final_result(IWOA)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kartik/Desktop/BTP/final.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> final_result(IWOA)
#
# /Users/kartik/Desktop/BTP/final.ipynb Cell 10 line 3
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=25'>26</a>   max_fe = 10000 * dimension
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=26'>27</a>   term_dict = {
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=27'>28</a>     "max_fe": max_fe
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=28'>29</a>   }
# ---> <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=29'>30</a>   best_position, best_fitness = model.solve(problem_dict, termination=term_dict)
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=30'>31</a>   run_result = np.append(run_result, best_fitness)
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=31'>32</a> WOAResults[func_map_key_name][dimension][pop_size] = np.mean(run_result)
#
# /Users/kartik/Desktop/BTP/final.ipynb Cell 10 line 2
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=19'>20</a> opt_alg = ImprovedWhaleOptimization(opt_func, constraints, self.pop_size, b, a, a_step, problem_dict["dim"], maximize)
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=21'>22</a> for t in range(self.epoch):
# ---> <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=22'>23</a>     opt_alg.optimize(t, self.epoch, termination["max_fe"])
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=23'>24</a> return opt_alg.best_solutions()
#
# /Users/kartik/Desktop/BTP/final.ipynb Cell 10 line 4
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=42'>43</a>     else:
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=43'>44</a>         new_s = self._attack(s, best_sol)
# ---> <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=44'>45</a>     new_sols.append(self._constrain_solution(new_s))
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=46'>47</a> de_sol = []
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=47'>48</a> for s in new_sols:
#
# /Users/kartik/Desktop/BTP/final.ipynb Cell 10 line 1
#     <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=145'>146</a>     if sol[i] > self._constraints[1][i]:
#     <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=146'>147</a>         sol[i] = self._constraints[1][i]
# --> <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=148'>149</a>     constrain_s.append(sol[i])
#     <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X36sZmlsZQ%3D%3D?line=150'>151</a> return constrain_s
#
# KeyboardInterrupt:

# %% [markdown]
# ## Original Whale Optimisation Algorithm

# %%
final_result(OriginalWOA)
# Out:
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: Solving single objective optimization problem.
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 1, Current best: 1608.3068268294792, Global best: 1608.3068268294792, Runtime: 0.00680 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 2, Current best: 1600.7870088917118, Global best: 1600.7870088917118, Runtime: 0.00503 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 3, Current best: 1417.7444247500705, Global best: 1417.7444247500705, Runtime: 0.00397 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 4, Current best: 1292.476715618967, Global best: 1292.476715618967, Runtime: 0.00488 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 5, Current best: 1229.7340211166313, Global best: 1229.7340211166313, Runtime: 0.00220 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 6, Current best: 1229.7340211166313, Global best: 1229.7340211166313, Runtime: 0.00394 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 7, Current best: 1194.444064787455, Global best: 1194.444064787455, Runtime: 0.00331 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 8, Current best: 1147.8028223469987, Global best: 1147.8028223469987, Runtime: 0.00406 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 9, Current best: 985.0517808857602, Global best: 985.0517808857602, Runtime: 0.00561 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 10, Current best: 946.6498437820951, Global best: 946.6498437820951, Runtime: 0.00282 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 11, Current best: 934.2734178238218, Global best: 934.2734178238218, Runtime: 0.00358 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 12, Current best: 914.9887444013742, Global best: 914.9887444013742, Runtime: 0.00528 seconds
# 2023/10/04 06:23:00 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 13, Current best: 904.1802174920391, Global best: 904.1802174920391, Runtime: 0.00314 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 14, Current best: 883.983836427946, Global best: 883.983836427946, Runtime: 0.00312 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 15, Current best: 848.0656379419329, Global best: 848.0656379419329, Runtime: 0.00321 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 16, Current best: 836.1853347485701, Global best: 836.1853347485701, Runtime: 0.00394 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 17, Current best: 832.6181602300767, Global best: 832.6181602300767, Runtime: 0.00314 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 18, Current best: 821.5062901500656, Global best: 821.5062901500656, Runtime: 0.00463 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 19, Current best: 818.6496995403879, Global best: 818.6496995403879, Runtime: 0.00439 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 20, Current best: 814.790798408892, Global best: 814.790798408892, Runtime: 0.00220 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 21, Current best: 810.9260312751326, Global best: 810.9260312751326, Runtime: 0.00813 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 22, Current best: 807.2910991047615, Global best: 807.2910991047615, Runtime: 0.00229 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 23, Current best: 807.0213004882455, Global best: 807.0213004882455, Runtime: 0.00455 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 24, Current best: 807.0012276324178, Global best: 807.0012276324178, Runtime: 0.01127 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 25, Current best: 806.6206973532085, Global best: 806.6206973532085, Runtime: 0.00715 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 26, Current best: 806.6206973532085, Global best: 806.6206973532085, Runtime: 0.00419 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 27, Current best: 806.156115833476, Global best: 806.156115833476, Runtime: 0.00744 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 28, Current best: 806.156115833476, Global best: 806.156115833476, Runtime: 0.00503 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 29, Current best: 805.3779427574744, Global best: 805.3779427574744, Runtime: 0.00452 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 30, Current best: 805.3614368795636, Global best: 805.3614368795636, Runtime: 0.00611 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 31, Current best: 805.3540068361972, Global best: 805.3540068361972, Runtime: 0.00273 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 32, Current best: 804.8122863503278, Global best: 804.8122863503278, Runtime: 0.00542 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 33, Current best: 804.8122863503278, Global best: 804.8122863503278, Runtime: 0.00643 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 34, Current best: 804.0019066734299, Global best: 804.0019066734299, Runtime: 0.00293 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 35, Current best: 803.9308791748572, Global best: 803.9308791748572, Runtime: 0.00302 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 36, Current best: 803.2187662967513, Global best: 803.2187662967513, Runtime: 0.00410 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 37, Current best: 803.0806865955461, Global best: 803.0806865955461, Runtime: 0.00421 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 38, Current best: 802.5445868424846, Global best: 802.5445868424846, Runtime: 0.00904 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 39, Current best: 802.4574394971035, Global best: 802.4574394971035, Runtime: 0.00268 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 40, Current best: 802.4002500342086, Global best: 802.4002500342086, Runtime: 0.00429 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 41, Current best: 802.2327757735413, Global best: 802.2327757735413, Runtime: 0.00316 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 42, Current best: 802.2327757735413, Global best: 802.2327757735413, Runtime: 0.00308 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 43, Current best: 802.2327757735413, Global best: 802.2327757735413, Runtime: 0.00613 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 44, Current best: 802.2327757735413, Global best: 802.2327757735413, Runtime: 0.00354 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 45, Current best: 802.229136761451, Global best: 802.229136761451, Runtime: 0.00362 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 46, Current best: 802.2288577648985, Global best: 802.2288577648985, Runtime: 0.03592 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 47, Current best: 802.2288577648985, Global best: 802.2288577648985, Runtime: 0.00320 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 48, Current best: 802.2288577648985, Global best: 802.2288577648985, Runtime: 0.00552 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 49, Current best: 802.2277971392892, Global best: 802.2277971392892, Runtime: 0.00321 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 50, Current best: 802.2277971392892, Global best: 802.2277971392892, Runtime: 0.00411 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 51, Current best: 802.2277971392892, Global best: 802.2277971392892, Runtime: 0.00303 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 52, Current best: 802.1585093071936, Global best: 802.1585093071936, Runtime: 0.00438 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 53, Current best: 802.1585093071936, Global best: 802.1585093071936, Runtime: 0.00336 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 54, Current best: 802.1579596537562, Global best: 802.1579596537562, Runtime: 0.00335 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 55, Current best: 802.1577812556919, Global best: 802.1577812556919, Runtime: 0.00277 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 56, Current best: 802.1577155631536, Global best: 802.1577155631536, Runtime: 0.00292 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 57, Current best: 802.1576975375076, Global best: 802.1576975375076, Runtime: 0.04189 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 58, Current best: 802.1529584543086, Global best: 802.1529584543086, Runtime: 0.00451 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 59, Current best: 802.1529584543086, Global best: 802.1529584543086, Runtime: 0.00319 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 60, Current best: 802.1512335584858, Global best: 802.1512335584858, Runtime: 0.00241 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 61, Current best: 802.1487891563786, Global best: 802.1487891563786, Runtime: 0.00697 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 62, Current best: 802.1487891563786, Global best: 802.1487891563786, Runtime: 0.00479 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 63, Current best: 802.148708070076, Global best: 802.148708070076, Runtime: 0.00246 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 64, Current best: 802.148708070076, Global best: 802.148708070076, Runtime: 0.00622 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 65, Current best: 802.1478169734212, Global best: 802.1478169734212, Runtime: 0.00445 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 66, Current best: 802.1474202321565, Global best: 802.1474202321565, Runtime: 0.00249 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 67, Current best: 802.1470963453611, Global best: 802.1470963453611, Runtime: 0.00325 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 68, Current best: 802.141952685849, Global best: 802.141952685849, Runtime: 0.00337 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 69, Current best: 802.141952685849, Global best: 802.141952685849, Runtime: 0.00519 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 70, Current best: 802.1414408787882, Global best: 802.1414408787882, Runtime: 0.00424 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 71, Current best: 802.1413243263642, Global best: 802.1413243263642, Runtime: 0.00654 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 72, Current best: 802.1412218321842, Global best: 802.1412218321842, Runtime: 0.00393 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 73, Current best: 802.1412129816521, Global best: 802.1412129816521, Runtime: 0.00430 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 74, Current best: 802.1411449264294, Global best: 802.1411449264294, Runtime: 0.00441 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 75, Current best: 802.1411442085548, Global best: 802.1411442085548, Runtime: 0.00246 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 76, Current best: 802.1411442085548, Global best: 802.1411442085548, Runtime: 0.00551 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 77, Current best: 802.1411245651177, Global best: 802.1411245651177, Runtime: 0.00417 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 78, Current best: 802.1404844671781, Global best: 802.1404844671781, Runtime: 0.00334 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 79, Current best: 802.1404844671781, Global best: 802.1404844671781, Runtime: 0.00510 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 80, Current best: 802.1403233783246, Global best: 802.1403233783246, Runtime: 0.00257 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 81, Current best: 802.139316033791, Global best: 802.139316033791, Runtime: 0.00509 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 82, Current best: 802.1384545134385, Global best: 802.1384545134385, Runtime: 0.00244 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 83, Current best: 802.1377171052318, Global best: 802.1377171052318, Runtime: 0.00437 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 84, Current best: 802.1375625461453, Global best: 802.1375625461453, Runtime: 0.00389 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 85, Current best: 802.1374738771899, Global best: 802.1374738771899, Runtime: 0.00423 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 86, Current best: 802.1374738771899, Global best: 802.1374738771899, Runtime: 0.00591 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 87, Current best: 802.1374738771899, Global best: 802.1374738771899, Runtime: 0.00453 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 88, Current best: 802.1374738771899, Global best: 802.1374738771899, Runtime: 0.00509 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 89, Current best: 802.1374603221593, Global best: 802.1374603221593, Runtime: 0.00535 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 90, Current best: 802.1374603221593, Global best: 802.1374603221593, Runtime: 0.00584 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 91, Current best: 802.1374602834867, Global best: 802.1374602834867, Runtime: 0.00383 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 92, Current best: 802.1374599090424, Global best: 802.1374599090424, Runtime: 0.00408 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 93, Current best: 802.1374599090424, Global best: 802.1374599090424, Runtime: 0.00533 seconds
# 2023/10/04 06:23:01 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 94, Current best: 802.1374599090424, Global best: 802.1374599090424, Runtime: 0.00804 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 95, Current best: 802.1374597956682, Global best: 802.1374597956682, Runtime: 0.01358 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 96, Current best: 802.1374584652639, Global best: 802.1374584652639, Runtime: 0.00687 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 97, Current best: 802.137457964592, Global best: 802.137457964592, Runtime: 0.02153 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 98, Current best: 802.1374575251214, Global best: 802.1374575251214, Runtime: 0.00715 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 99, Current best: 802.1374573502326, Global best: 802.1374573502326, Runtime: 0.00306 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 100, Current best: 802.1374563786574, Global best: 802.1374563786574, Runtime: 0.00620 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 101, Current best: 802.1374561747778, Global best: 802.1374561747778, Runtime: 0.00685 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 102, Current best: 802.1374557553568, Global best: 802.1374557553568, Runtime: 0.00290 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 103, Current best: 802.1374546702178, Global best: 802.1374546702178, Runtime: 0.00796 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 104, Current best: 802.1374541998553, Global best: 802.1374541998553, Runtime: 0.03655 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 105, Current best: 802.1374532220148, Global best: 802.1374532220148, Runtime: 0.00309 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 106, Current best: 802.1374500881846, Global best: 802.1374500881846, Runtime: 0.00643 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 107, Current best: 802.1374461789969, Global best: 802.1374461789969, Runtime: 0.00322 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 108, Current best: 802.1374439980766, Global best: 802.1374439980766, Runtime: 0.00507 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 109, Current best: 802.1374390411991, Global best: 802.1374390411991, Runtime: 0.00407 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 110, Current best: 802.1374387457788, Global best: 802.1374387457788, Runtime: 0.00311 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 111, Current best: 802.1374387457788, Global best: 802.1374387457788, Runtime: 0.00317 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 112, Current best: 802.1374387457788, Global best: 802.1374387457788, Runtime: 0.00259 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 113, Current best: 802.1374386345391, Global best: 802.1374386345391, Runtime: 0.00398 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 114, Current best: 802.1374386127097, Global best: 802.1374386127097, Runtime: 0.00418 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 115, Current best: 802.1309290539641, Global best: 802.1309290539641, Runtime: 0.00343 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 116, Current best: 802.1302713348234, Global best: 802.1302713348234, Runtime: 0.00758 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 117, Current best: 802.1300489360563, Global best: 802.1300489360563, Runtime: 0.00292 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 118, Current best: 802.1299198124568, Global best: 802.1299198124568, Runtime: 0.00373 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 119, Current best: 802.1297361152045, Global best: 802.1297361152045, Runtime: 0.00783 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 120, Current best: 802.1295617955102, Global best: 802.1295617955102, Runtime: 0.00350 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 121, Current best: 802.1292601482317, Global best: 802.1292601482317, Runtime: 0.00481 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 122, Current best: 802.1283542437674, Global best: 802.1283542437674, Runtime: 0.00452 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 123, Current best: 802.1258807943896, Global best: 802.1258807943896, Runtime: 0.00511 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 124, Current best: 802.1208385994123, Global best: 802.1208385994123, Runtime: 0.00333 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 125, Current best: 802.1206337992962, Global best: 802.1206337992962, Runtime: 0.00381 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 126, Current best: 802.1199939272974, Global best: 802.1199939272974, Runtime: 0.00305 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 127, Current best: 802.1185938635085, Global best: 802.1185938635085, Runtime: 0.00310 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 128, Current best: 802.1167794451425, Global best: 802.1167794451425, Runtime: 0.00362 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 129, Current best: 802.1167794451425, Global best: 802.1167794451425, Runtime: 0.00231 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 130, Current best: 802.1132625135842, Global best: 802.1132625135842, Runtime: 0.01850 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 131, Current best: 802.1096812531598, Global best: 802.1096812531598, Runtime: 0.00359 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 132, Current best: 802.1092404733428, Global best: 802.1092404733428, Runtime: 0.00331 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 133, Current best: 802.1069672817235, Global best: 802.1069672817235, Runtime: 0.02344 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 134, Current best: 802.1031727350756, Global best: 802.1031727350756, Runtime: 0.00425 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 135, Current best: 802.0986030694563, Global best: 802.0986030694563, Runtime: 0.00229 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 136, Current best: 802.0954650589553, Global best: 802.0954650589553, Runtime: 0.00503 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 137, Current best: 802.0769713908757, Global best: 802.0769713908757, Runtime: 0.00297 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 138, Current best: 802.0690105003127, Global best: 802.0690105003127, Runtime: 0.00293 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 139, Current best: 802.0371534098001, Global best: 802.0371534098001, Runtime: 0.00386 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 140, Current best: 802.0114546878152, Global best: 802.0114546878152, Runtime: 0.00270 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 141, Current best: 801.9824266403923, Global best: 801.9824266403923, Runtime: 0.00353 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 142, Current best: 801.9793747092247, Global best: 801.9793747092247, Runtime: 0.00547 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 143, Current best: 801.9737512900887, Global best: 801.9737512900887, Runtime: 0.00289 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 144, Current best: 801.9737090140459, Global best: 801.9737090140459, Runtime: 0.00654 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 145, Current best: 801.973653487459, Global best: 801.973653487459, Runtime: 0.00540 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 146, Current best: 801.973653487459, Global best: 801.973653487459, Runtime: 0.00518 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 147, Current best: 801.9736178927577, Global best: 801.9736178927577, Runtime: 0.00400 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 148, Current best: 801.9736178927577, Global best: 801.9736178927577, Runtime: 0.00652 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 149, Current best: 801.9736178927577, Global best: 801.9736178927577, Runtime: 0.00899 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 150, Current best: 801.9736178927577, Global best: 801.9736178927577, Runtime: 0.00490 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 151, Current best: 801.9736178927577, Global best: 801.9736178927577, Runtime: 0.01314 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 152, Current best: 801.9736178338662, Global best: 801.9736178338662, Runtime: 0.00524 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 153, Current best: 801.9736177883453, Global best: 801.9736177883453, Runtime: 0.00519 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 154, Current best: 801.9736177883453, Global best: 801.9736177883453, Runtime: 0.00429 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 155, Current best: 801.9736177883453, Global best: 801.9736177883453, Runtime: 0.00418 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 156, Current best: 801.9736177883453, Global best: 801.9736177883453, Runtime: 0.00378 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 157, Current best: 801.9736177883453, Global best: 801.9736177883453, Runtime: 0.00384 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 158, Current best: 801.9735132028115, Global best: 801.9735132028115, Runtime: 0.00368 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 159, Current best: 801.9735132028115, Global best: 801.9735132028115, Runtime: 0.03680 seconds
# 2023/10/04 06:23:02 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 160, Current best: 801.9734931818799, Global best: 801.9734931818799, Runtime: 0.00478 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 161, Current best: 801.9734765311597, Global best: 801.9734765311597, Runtime: 0.00369 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 162, Current best: 801.9734765311597, Global best: 801.9734765311597, Runtime: 0.00287 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 163, Current best: 801.9734699155554, Global best: 801.9734699155554, Runtime: 0.00494 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 164, Current best: 801.9734292495091, Global best: 801.9734292495091, Runtime: 0.00647 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 165, Current best: 801.9733362776833, Global best: 801.9733362776833, Runtime: 0.00558 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 166, Current best: 801.9732094377152, Global best: 801.9732094377152, Runtime: 0.00421 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 167, Current best: 801.9730149937998, Global best: 801.9730149937998, Runtime: 0.00382 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 168, Current best: 801.9726394567799, Global best: 801.9726394567799, Runtime: 0.00549 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 169, Current best: 801.9723101563972, Global best: 801.9723101563972, Runtime: 0.00699 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 170, Current best: 801.9722968182733, Global best: 801.9722968182733, Runtime: 0.00314 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 171, Current best: 801.9722742809834, Global best: 801.9722742809834, Runtime: 0.00431 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 172, Current best: 801.9722668573993, Global best: 801.9722668573993, Runtime: 0.00924 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 173, Current best: 801.9722668573993, Global best: 801.9722668573993, Runtime: 0.00304 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 174, Current best: 801.9721636789934, Global best: 801.9721636789934, Runtime: 0.00324 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 175, Current best: 801.9720006263071, Global best: 801.9720006263071, Runtime: 0.01061 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 176, Current best: 801.9719792637242, Global best: 801.9719792637242, Runtime: 0.16095 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 177, Current best: 801.971726076526, Global best: 801.971726076526, Runtime: 0.00686 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 178, Current best: 801.971726076526, Global best: 801.971726076526, Runtime: 0.00525 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 179, Current best: 801.971726076526, Global best: 801.971726076526, Runtime: 0.00289 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 180, Current best: 801.9717233800504, Global best: 801.9717233800504, Runtime: 0.00293 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 181, Current best: 801.9717024406635, Global best: 801.9717024406635, Runtime: 0.00982 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 182, Current best: 801.9717024406635, Global best: 801.9717024406635, Runtime: 0.00451 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 183, Current best: 801.9717024406635, Global best: 801.9717024406635, Runtime: 0.00512 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 184, Current best: 801.9715765480228, Global best: 801.9715765480228, Runtime: 0.01066 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 185, Current best: 801.9714664421485, Global best: 801.9714664421485, Runtime: 0.00411 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 186, Current best: 801.9714664421485, Global best: 801.9714664421485, Runtime: 0.00324 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 187, Current best: 801.9711894167231, Global best: 801.9711894167231, Runtime: 0.00180 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 188, Current best: 801.9707753286972, Global best: 801.9707753286972, Runtime: 0.00236 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 189, Current best: 801.9700652367361, Global best: 801.9700652367361, Runtime: 0.00254 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 190, Current best: 801.9689855041065, Global best: 801.9689855041065, Runtime: 0.00333 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 191, Current best: 801.9673240319343, Global best: 801.9673240319343, Runtime: 0.00280 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 192, Current best: 801.9657818067482, Global best: 801.9657818067482, Runtime: 0.00269 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 193, Current best: 801.9657818067482, Global best: 801.9657818067482, Runtime: 0.00165 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 194, Current best: 801.9651662111685, Global best: 801.9651662111685, Runtime: 0.00378 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 195, Current best: 801.9651209318992, Global best: 801.9651209318992, Runtime: 0.01550 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 196, Current best: 801.9651158654508, Global best: 801.9651158654508, Runtime: 0.05335 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 197, Current best: 801.9651158654508, Global best: 801.9651158654508, Runtime: 0.00523 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 198, Current best: 801.9651157052546, Global best: 801.9651157052546, Runtime: 0.00410 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 199, Current best: 801.9651076252004, Global best: 801.9651076252004, Runtime: 0.00383 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 200, Current best: 801.9651075548302, Global best: 801.9651075548302, Runtime: 0.00423 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 201, Current best: 801.9651075420111, Global best: 801.9651075420111, Runtime: 0.00396 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 202, Current best: 801.9650824231296, Global best: 801.9650824231296, Runtime: 0.00749 seconds
# 2023/10/04 06:23:03 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 203, Current best: 801.9650545942418, Global best: 801.9650545942418, Runtime: 0.00393 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 204, Current best: 801.965051130667, Global best: 801.965051130667, Runtime: 0.00821 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 205, Current best: 801.965041441232, Global best: 801.965041441232, Runtime: 0.00321 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 206, Current best: 801.9650337988264, Global best: 801.9650337988264, Runtime: 0.00269 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 207, Current best: 801.9650196670564, Global best: 801.9650196670564, Runtime: 0.00350 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 208, Current best: 801.9649982162582, Global best: 801.9649982162582, Runtime: 0.00405 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 209, Current best: 801.9649727161602, Global best: 801.9649727161602, Runtime: 0.00250 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 210, Current best: 801.964966386655, Global best: 801.964966386655, Runtime: 0.00395 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 211, Current best: 801.9649638402344, Global best: 801.9649638402344, Runtime: 0.00184 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 212, Current best: 801.9648764642143, Global best: 801.9648764642143, Runtime: 0.00358 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 213, Current best: 801.9647506029273, Global best: 801.9647506029273, Runtime: 0.00323 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 214, Current best: 801.9646354767542, Global best: 801.9646354767542, Runtime: 0.00353 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 215, Current best: 801.9643443636339, Global best: 801.9643443636339, Runtime: 0.00799 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 216, Current best: 801.963698234026, Global best: 801.963698234026, Runtime: 0.00369 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 217, Current best: 801.963698234026, Global best: 801.963698234026, Runtime: 0.02414 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 218, Current best: 801.9635565986723, Global best: 801.9635565986723, Runtime: 0.02247 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 219, Current best: 801.9634830725381, Global best: 801.9634830725381, Runtime: 0.00560 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 220, Current best: 801.9634122307266, Global best: 801.9634122307266, Runtime: 0.00425 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 221, Current best: 801.9633602183808, Global best: 801.9633602183808, Runtime: 0.02829 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 222, Current best: 801.9633538355076, Global best: 801.9633538355076, Runtime: 0.00484 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 223, Current best: 801.9633422189993, Global best: 801.9633422189993, Runtime: 0.00394 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 224, Current best: 801.9633399337829, Global best: 801.9633399337829, Runtime: 0.00500 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 225, Current best: 801.9632748705512, Global best: 801.9632748705512, Runtime: 0.00241 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 226, Current best: 801.9631924235736, Global best: 801.9631924235736, Runtime: 0.00585 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 227, Current best: 801.9630775968426, Global best: 801.9630775968426, Runtime: 0.00324 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 228, Current best: 801.9630213854765, Global best: 801.9630213854765, Runtime: 0.00281 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 229, Current best: 801.9629029383968, Global best: 801.9629029383968, Runtime: 0.00548 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 230, Current best: 801.9626196974939, Global best: 801.9626196974939, Runtime: 0.00478 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 231, Current best: 801.9625544447875, Global best: 801.9625544447875, Runtime: 0.06419 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 232, Current best: 801.9622730917539, Global best: 801.9622730917539, Runtime: 0.00162 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 233, Current best: 801.9617034105687, Global best: 801.9617034105687, Runtime: 0.00796 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 234, Current best: 801.9600294264774, Global best: 801.9600294264774, Runtime: 0.00193 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 235, Current best: 801.9583844733444, Global best: 801.9583844733444, Runtime: 0.00191 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 236, Current best: 801.951410066818, Global best: 801.951410066818, Runtime: 0.00890 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 237, Current best: 801.951410066818, Global best: 801.951410066818, Runtime: 0.00975 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 238, Current best: 801.9369803186031, Global best: 801.9369803186031, Runtime: 0.00573 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 239, Current best: 801.9369803186031, Global best: 801.9369803186031, Runtime: 0.00242 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 240, Current best: 801.9369803186031, Global best: 801.9369803186031, Runtime: 0.00552 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 241, Current best: 801.9333276129646, Global best: 801.9333276129646, Runtime: 0.00393 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 242, Current best: 801.926119332461, Global best: 801.926119332461, Runtime: 0.01298 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 243, Current best: 801.9233716815221, Global best: 801.9233716815221, Runtime: 0.00358 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 244, Current best: 801.9144330301658, Global best: 801.9144330301658, Runtime: 0.00835 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 245, Current best: 801.8902886216463, Global best: 801.8902886216463, Runtime: 0.00393 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 246, Current best: 801.8792924118444, Global best: 801.8792924118444, Runtime: 0.01012 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 247, Current best: 801.866084444683, Global best: 801.866084444683, Runtime: 0.00411 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 248, Current best: 801.8654164257205, Global best: 801.8654164257205, Runtime: 0.00745 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 249, Current best: 801.8610975123627, Global best: 801.8610975123627, Runtime: 0.00254 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 250, Current best: 801.8604610399653, Global best: 801.8604610399653, Runtime: 0.00329 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 251, Current best: 801.8525308241201, Global best: 801.8525308241201, Runtime: 0.00444 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 252, Current best: 801.8442510888277, Global best: 801.8442510888277, Runtime: 0.00351 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 253, Current best: 801.8335869130051, Global best: 801.8335869130051, Runtime: 0.00305 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 254, Current best: 801.8176895696922, Global best: 801.8176895696922, Runtime: 0.00496 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 255, Current best: 801.8176895696922, Global best: 801.8176895696922, Runtime: 0.00507 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 256, Current best: 801.8166137526136, Global best: 801.8166137526136, Runtime: 0.00159 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 257, Current best: 801.8166137526136, Global best: 801.8166137526136, Runtime: 0.00374 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 258, Current best: 801.8166137526136, Global best: 801.8166137526136, Runtime: 0.00174 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 259, Current best: 801.8166137526136, Global best: 801.8166137526136, Runtime: 0.01828 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 260, Current best: 801.8166137526136, Global best: 801.8166137526136, Runtime: 0.00428 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 261, Current best: 801.8165974194048, Global best: 801.8165974194048, Runtime: 0.00503 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 262, Current best: 801.8150967373795, Global best: 801.8150967373795, Runtime: 0.00440 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 263, Current best: 801.8134964451875, Global best: 801.8134964451875, Runtime: 0.00168 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 264, Current best: 801.8134964451875, Global best: 801.8134964451875, Runtime: 0.00408 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 265, Current best: 801.7885189130883, Global best: 801.7885189130883, Runtime: 0.00141 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 266, Current best: 801.7876266979052, Global best: 801.7876266979052, Runtime: 0.00299 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 267, Current best: 801.7614007508205, Global best: 801.7614007508205, Runtime: 0.00301 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 268, Current best: 801.739781080394, Global best: 801.739781080394, Runtime: 0.00179 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 269, Current best: 801.6331766884833, Global best: 801.6331766884833, Runtime: 0.00219 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 270, Current best: 801.391700440975, Global best: 801.391700440975, Runtime: 0.00156 seconds
# 2023/10/04 06:23:04 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 271, Current best: 801.391700440975, Global best: 801.391700440975, Runtime: 0.00321 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 272, Current best: 801.391700440975, Global best: 801.391700440975, Runtime: 0.00397 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 273, Current best: 801.391700440975, Global best: 801.391700440975, Runtime: 0.00485 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 274, Current best: 801.391700440975, Global best: 801.391700440975, Runtime: 0.01036 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 275, Current best: 801.391700440975, Global best: 801.391700440975, Runtime: 0.00310 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 276, Current best: 801.3633548312398, Global best: 801.3633548312398, Runtime: 0.00709 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 277, Current best: 801.3413265400841, Global best: 801.3413265400841, Runtime: 0.03406 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 278, Current best: 801.3413265400841, Global best: 801.3413265400841, Runtime: 0.00315 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 279, Current best: 801.3413265400841, Global best: 801.3413265400841, Runtime: 0.00236 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 280, Current best: 801.3407754553713, Global best: 801.3407754553713, Runtime: 0.00333 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 281, Current best: 801.3286565503171, Global best: 801.3286565503171, Runtime: 0.00441 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 282, Current best: 801.3286565503171, Global best: 801.3286565503171, Runtime: 0.00585 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 283, Current best: 801.3230292991454, Global best: 801.3230292991454, Runtime: 0.00175 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 284, Current best: 801.3084251989874, Global best: 801.3084251989874, Runtime: 0.00334 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 285, Current best: 801.3052340303379, Global best: 801.3052340303379, Runtime: 0.00281 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 286, Current best: 801.2887221940268, Global best: 801.2887221940268, Runtime: 0.00389 seconds
# 2023/10/04 06:23:05 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 287, Current best: 801.2873383343048, Global best: 801.2873383343048, Runtime: 0.00365 seconds
# ...
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 588, Current best: 757.9415388507053, Global best: 757.9415388507053, Runtime: 0.00225 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 589, Current best: 757.9415388507053, Global best: 757.9415388507053, Runtime: 0.00359 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 590, Current best: 757.9389952686012, Global best: 757.9389952686012, Runtime: 0.00887 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 591, Current best: 757.9389952686012, Global best: 757.9389952686012, Runtime: 0.00688 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 592, Current best: 757.9389725628973, Global best: 757.9389725628973, Runtime: 0.00233 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 593, Current best: 757.9378521220028, Global best: 757.9378521220028, Runtime: 0.00443 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 594, Current best: 757.9362797035737, Global best: 757.9362797035737, Runtime: 0.00544 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 595, Current best: 757.935387783712, Global best: 757.935387783712, Runtime: 0.00356 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 596, Current best: 757.932013970069, Global best: 757.932013970069, Runtime: 0.00381 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 597, Current best: 757.9296392135499, Global best: 757.9296392135499, Runtime: 0.00440 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 598, Current best: 757.9237348343399, Global best: 757.9237348343399, Runtime: 0.00418 seconds
# 2023/10/04 06:23:11 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 599, Current best: 757.9088746165517, Global best: 757.9088746165517, Runtime: 0.00608 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 600, Current best: 757.8969545118287, Global best: 757.8969545118287, Runtime: 0.00745 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 601, Current best: 757.8969545118287, Global best: 757.8969545118287, Runtime: 0.00371 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 602, Current best: 757.8880656565156, Global best: 757.8880656565156, Runtime: 0.00180 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 603, Current best: 757.8880656565156, Global best: 757.8880656565156, Runtime: 0.00886 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 604, Current best: 757.8876514184659, Global best: 757.8876514184659, Runtime: 0.04827 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 605, Current best: 757.8857941548422, Global best: 757.8857941548422, Runtime: 0.00278 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 606, Current best: 757.8847797018399, Global best: 757.8847797018399, Runtime: 0.00354 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 607, Current best: 757.8842106635318, Global best: 757.8842106635318, Runtime: 0.00520 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 608, Current best: 757.8820141670212, Global best: 757.8820141670212, Runtime: 0.00387 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 609, Current best: 757.8711774209482, Global best: 757.8711774209482, Runtime: 0.00789 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 610, Current best: 757.8675299438992, Global best: 757.8675299438992, Runtime: 0.01116 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 611, Current best: 757.8675299438992, Global best: 757.8675299438992, Runtime: 0.00351 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 612, Current best: 757.8660570151956, Global best: 757.8660570151956, Runtime: 0.00634 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 613, Current best: 757.8660570151956, Global best: 757.8660570151956, Runtime: 0.00842 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 614, Current best: 757.8659987636546, Global best: 757.8659987636546, Runtime: 0.00518 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 615, Current best: 757.865986427973, Global best: 757.865986427973, Runtime: 0.00381 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 616, Current best: 757.8659855310024, Global best: 757.8659855310024, Runtime: 0.00167 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 617, Current best: 757.8659456131024, Global best: 757.8659456131024, Runtime: 0.00577 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 618, Current best: 757.8639220096272, Global best: 757.8639220096272, Runtime: 0.00376 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 619, Current best: 757.8639220096272, Global best: 757.8639220096272, Runtime: 0.00142 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 620, Current best: 757.8638222766997, Global best: 757.8638222766997, Runtime: 0.08192 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 621, Current best: 757.8635776334302, Global best: 757.8635776334302, Runtime: 0.00426 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 622, Current best: 757.8634512552171, Global best: 757.8634512552171, Runtime: 0.01719 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 623, Current best: 757.8632608064936, Global best: 757.8632608064936, Runtime: 0.00606 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 624, Current best: 757.8628135712516, Global best: 757.8628135712516, Runtime: 0.00600 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 625, Current best: 757.8626459849977, Global best: 757.8626459849977, Runtime: 0.00483 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 626, Current best: 757.8623130577323, Global best: 757.8623130577323, Runtime: 0.00735 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 627, Current best: 757.8620805198319, Global best: 757.8620805198319, Runtime: 0.00555 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 628, Current best: 757.8618440044047, Global best: 757.8618440044047, Runtime: 0.00539 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 629, Current best: 757.8618104023132, Global best: 757.8618104023132, Runtime: 0.00354 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 630, Current best: 757.8618104023132, Global best: 757.8618104023132, Runtime: 0.00541 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 631, Current best: 757.861809009646, Global best: 757.861809009646, Runtime: 0.00314 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 632, Current best: 757.8616649009866, Global best: 757.8616649009866, Runtime: 0.00246 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 633, Current best: 757.861477600816, Global best: 757.861477600816, Runtime: 0.00281 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 634, Current best: 757.8614686540903, Global best: 757.8614686540903, Runtime: 0.00798 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 635, Current best: 757.8614500020622, Global best: 757.8614500020622, Runtime: 0.00480 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 636, Current best: 757.8614500020622, Global best: 757.8614500020622, Runtime: 0.00269 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 637, Current best: 757.8614500020622, Global best: 757.8614500020622, Runtime: 0.00323 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 638, Current best: 757.8614500020622, Global best: 757.8614500020622, Runtime: 0.00443 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 639, Current best: 757.8614500020622, Global best: 757.8614500020622, Runtime: 0.00295 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 640, Current best: 757.8614402539575, Global best: 757.8614402539575, Runtime: 0.00819 seconds
# 2023/10/04 06:23:12 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 641, Current best: 757.861427986441, Global best: 757.861427986441, Runtime: 0.01247 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 642, Current best: 757.8614201542792, Global best: 757.8614201542792, Runtime: 0.00313 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 643, Current best: 757.8614141232297, Global best: 757.8614141232297, Runtime: 0.00463 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 644, Current best: 757.861410474669, Global best: 757.861410474669, Runtime: 0.00471 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 645, Current best: 757.861410474669, Global best: 757.861410474669, Runtime: 0.02573 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 646, Current best: 757.8614100248329, Global best: 757.8614100248329, Runtime: 0.01550 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 647, Current best: 757.861370154712, Global best: 757.861370154712, Runtime: 0.00476 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 648, Current best: 757.8613288696216, Global best: 757.8613288696216, Runtime: 0.00437 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 649, Current best: 757.861256324125, Global best: 757.861256324125, Runtime: 0.00636 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 650, Current best: 757.8612185605454, Global best: 757.8612185605454, Runtime: 0.00383 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 651, Current best: 757.8611888422614, Global best: 757.8611888422614, Runtime: 0.00508 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 652, Current best: 757.8611074534379, Global best: 757.8611074534379, Runtime: 0.00302 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 653, Current best: 757.861022290293, Global best: 757.861022290293, Runtime: 0.00306 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 654, Current best: 757.8609690235455, Global best: 757.8609690235455, Runtime: 0.00546 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 655, Current best: 757.860957848646, Global best: 757.860957848646, Runtime: 0.00406 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 656, Current best: 757.8609330504337, Global best: 757.8609330504337, Runtime: 0.00438 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 657, Current best: 757.8602845325485, Global best: 757.8602845325485, Runtime: 0.00364 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 658, Current best: 757.8601855598582, Global best: 757.8601855598582, Runtime: 0.00267 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 659, Current best: 757.8596979927538, Global best: 757.8596979927538, Runtime: 0.00702 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 660, Current best: 757.8595965357804, Global best: 757.8595965357804, Runtime: 0.00475 seconds
# 2023/10/04 06:23:13 PM, INFO, __main__.OriginalWOA: >Problem: P, Epoch: 661, Current best: 757.8595965357804, Global best: 757.8595965357804, Runtime: 0.00540 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kartik/Desktop/BTP/final.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> final_result(OriginalWOA)
#
# /Users/kartik/Desktop/BTP/final.ipynb Cell 9 line 2
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=24'>25</a>   max_fe = 10000 * dimension
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=25'>26</a>   term_dict = {
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=26'>27</a>     "max_fe": max_fe
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=27'>28</a>   }
# ---> <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=28'>29</a>   best_position, best_fitness = model.solve(problem_dict, termination=term_dict)
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=29'>30</a>   run_result = np.append(run_result, best_fitness)
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=30'>31</a> WOAResults[func_map_key_name][dimension][pop_size] = np.mean(run_result)
#
# File /usr/local/lib/python3.11/site-packages/mealpy/optimizer.py:314, in Optimizer.solve(self, problem, mode, starting_positions, n_workers, termination)
#     311 time_epoch = time.perf_counter()
#     313 ## Evolve method will be called in child class
# --> 314 self.evolve(epoch)
#     316 # Update global best position, the population is sorted or not depended on algorithm's strategy
#     317 pop_temp, self.g_best = self.update_global_best_solution(self.pop)
#
# /Users/kartik/Desktop/BTP/final.ipynb Cell 9 line 8
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=81'>82</a>     pop_new.append([pos_new, None])
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=82'>83</a>     if self.mode not in self.AVAILABLE_MODES:
# ---> <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=83'>84</a>         target = self.get_target_wrapper(pos_new)
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=84'>85</a>         self.pop[idx] = self.get_better_solution(
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=85'>86</a>             self.pop[idx], [pos_new, target]
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=86'>87</a>         )
#      <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X11sZmlsZQ%3D%3D?line=87'>88</a> if self.mode in self.AVAILABLE_MODES:
#
# File /usr/local/lib/python3.11/site-packages/mealpy/optimizer.py:164, in Optimizer.get_target_wrapper(self, position, counted)
#     162 if counted:
#     163     self.nfe_counter += 1
# --> 164 objs = self.problem.fit_func(position)
#     165 if not self.problem.obj_is_list:
#     166     objs = [objs]
#
# File /usr/local/lib/python3.11/site-packages/opfunu/cec_based/cec2014.py:135, in F42014.evaluate(self, x, *args)
#     133 self.n_fe += 1
#     134 self.check_solution(x, self.dim_max, self.dim_supported)
# --> 135 z = np.dot(self.f_matrix, 2.048*(x - self.f_shift)/100) + 1
#     136 return operator.rosenbrock_func(z) + self.f_bias
#
# KeyboardInterrupt:

# %%
WOAResults
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kartik/Desktop/BTP/final.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/kartik/Desktop/BTP/final.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> WOAResults
#
# NameError: name 'WOAResults' is not defined

# %% [markdown]
# # Population Analysis

# %%
import matplotlib.pyplot as plt
def plot_dimension(model_names, year, dimension, title="Dimension CEC", file_name_queries=None, special=None):
  for model in model_names:
    folder_path = f'./results/{model}'
    all_dataframes = []
    file_list = os.listdir(folder_path)
    for file_name in file_list:
      if file_name_queries is None:
        if file_name.endswith(f'{year}.csv'):
          file_path = os.path.join(folder_path, file_name)
          print(file_path)
          df = pd.read_csv(file_path)
          df = df.transpose()
          all_dataframes.append(df)
      else:
        if file_name in file_name_queries and file_name.endswith(f'{year}.csv'):
          file_path = os.path.join(folder_path, file_name)
          print(file_path)
          df = pd.read_csv(file_path)
          df = df.transpose()
          all_dataframes.append(df)
    combined_df = pd.concat(all_dataframes, axis=0)
    average_df = combined_df.groupby(level=0).mean()
    average_df = average_df.transpose()
    average_df['Rank'] = average_df['10'].rank()
    plt.plot(average_df['Unnamed: 0'].astype(int).astype(str), average_df['Rank'], marker='o', linewidth=1, label=model)
    plt.title(f'{dimension} {title} {year}')
    plt.xlabel('Population Size')
    plt.ylabel('Average Rank')
    plt.grid(True, axis="y")
    plt.legend()
    if special is None:
      saving_file_name = f'./results/Plots/{dimension}-CEC-{year}.png'
    else:
      saving_file_name = f'./results/Plots/{dimension}-{special}-CEC-{year}.png'
    plt.savefig(saving_file_name, dpi=300, bbox_inches='tight')
  plt.clf()

# %%
all_algos = ['OriginalWOA', 'HI_WOA']

# %% [markdown]
# # Overall Average

# %%
for year in [2014, 2017]:
  for dimension in [10, 30, 50, 100]:
    plot_dimension(all_algos, year, dimension)

# %% [markdown]
# # Functions Categorization

# %%
unimodal_functions = []
composition_functions = []
typical_multimodal_functions = []

for func_num in range(1, 4):
  unimodal_functions.append(f'F{func_num}2014.csv')
for func_num in range(1, 3):
  unimodal_functions.append(f'F{func_num}2017.csv')

for func_num in range(23, 31):
  composition_functions.append(f'F{func_num}2014.csv')
for func_num in range(20, 30):
  composition_functions.append(f'F{func_num}2017.csv')

for func_num in range(4, 22):
  typical_multimodal_functions.append(f'F{func_num}2014.csv')
for func_num in range(3, 20):
  typical_multimodal_functions.append(f'F{func_num}2017.csv')

# %% [markdown]
# ## Unimodal Functions

# %%
for year in [2014, 2017]:
  for dimension in [10, 30, 50, 100]:
    plot_dimension(all_algos, year, dimension, "Dimension Unimodal", unimodal_functions, "unimodal")

# %% [markdown]
# ## Composition Functions

# %%
for year in [2014, 2017]:
  for dimension in [10, 30, 50, 100]:
    plot_dimension(all_algos, year, dimension, "Dimension Composition", composition_functions, "composition")
